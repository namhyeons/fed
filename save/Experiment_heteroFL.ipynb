# %%
def mv_average_10(lst):
    mv_lst = []
    for i in range(len(lst)-10):
        mv_lst.append(round(sum(lst[i:i+10]) / 10, 4))
    return mv_lst

# %%
# HeteroFL Paper Figure 2 Re-experiment

import matplotlib.pyplot as plt
import pickle

with open("cifar10/H[b]_P[0.0]_hetero_test.pkl", 'rb') as f:
    hetero_0 = pickle.load(f)

with open("cifar10/H[b]_P[0.2]_hetero_test.pkl", 'rb') as f:
    hetero_2 = pickle.load(f)

with open("cifar10/H[b]_P[0.4]_hetero_test.pkl", 'rb') as f:
    hetero_4 = pickle.load(f)

with open("cifar10/H[b]_P[0.6]_hetero_test.pkl", 'rb') as f:
    hetero_6 = pickle.load(f)

with open("cifar10/H[b]_P[0.8]_hetero_test.pkl", 'rb') as f:
    hetero_8 = pickle.load(f)

with open("cifar10/H[b]_P[1.0]_hetero_test.pkl", 'rb') as f:
    hetero_10 = pickle.load(f)

with open("cifar10/H[e]_P[0.0]_hetero_test.pkl", 'rb') as f:
    hetero_0_e = pickle.load(f)

with open("cifar10/H[e]_P[0.2]_hetero_test.pkl", 'rb') as f:
    hetero_2_e = pickle.load(f)

with open("cifar10/H[e]_P[0.4]_hetero_test.pkl", 'rb') as f:
    hetero_4_e = pickle.load(f)

with open("cifar10/H[e]_P[0.6]_hetero_test.pkl", 'rb') as f:
    hetero_6_e = pickle.load(f)

with open("cifar10/H[e]_P[0.8]_hetero_test.pkl", 'rb') as f:
    hetero_8_e = pickle.load(f)

with open("cifar10/H[e]_P[1.0]_hetero_test.pkl", 'rb') as f:
    hetero_10_e = pickle.load(f)

x = list(range(0,12,2))
for i in range(len(x)):
    x[i] = x[i] / 10

plt.figure(dpi=120)
plt.grid(b=True, which='major', axis='both')
plt.plot(x, [hetero_0[-1], hetero_2[-1], hetero_4[-1], hetero_6[-1], hetero_8[-1], hetero_10[-1]], label='a-b')
plt.plot(x, [hetero_0_e[-1], hetero_2_e[-1], hetero_4_e[-1], hetero_6_e[-1], hetero_8_e[-1], hetero_10_e[-1]], label='a-e')
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
import pickle


with open("cifar10/N[100]_R[1000]_E[5]_iid[1]_PR[1]_F[1]_LR[0.1]_LD[0.998]_B[-1]_RB[0]_S[1]_hetero_3.pkl", 'rb') as f:
    main_3 = pickle.load(f)

with open("cifar10/N[100]_R[1000]_E[5]_iid[1]_PR[1]_F[1]_LR[0.1]_LD[0.998]_B[-1]_RB[0]_S[1]_hetero_4.pkl", 'rb') as f:
    main_4 = pickle.load(f)

with open("cifar10/N[100]_R[1000]_E[5]_iid[1]_PR[1]_F[1]_LR[0.1]_LD[0.998]_B[0]_RB[0]_S[0]_hetero_3.pkl", 'rb') as f:
    base_0_3 = pickle.load(f)

with open("cifar10/N[100]_R[1000]_E[5]_iid[1]_PR[1]_F[1]_LR[0.1]_LD[0.998]_B[0]_RB[0]_S[0]_hetero_4.pkl", 'rb') as f:
    base_0_4 = pickle.load(f)

with open("cifar10/N[100]_R[1000]_E[5]_iid[1]_PR[1]_F[1]_LR[0.1]_LD[0.998]_B[1]_RB[0]_S[0]_hetero_3.pkl", 'rb') as f:
    base_1_3 = pickle.load(f)

with open("cifar10/N[100]_R[1000]_E[5]_iid[1]_PR[1]_F[1]_LR[0.1]_LD[0.998]_B[1]_RB[0]_S[0]_hetero_4.pkl", 'rb') as f:
    base_1_4 = pickle.load(f)

with open("cifar10/N[100]_R[1000]_E[5]_iid[1]_PR[1]_F[1]_LR[0.1]_LD[0.998]_B[2]_RB[0]_S[0]_hetero_3.pkl", 'rb') as f:
    base_2_3 = pickle.load(f)

with open("cifar10/N[100]_R[1000]_E[5]_iid[1]_PR[1]_F[1]_LR[0.1]_LD[0.998]_B[2]_RB[0]_S[0]_hetero_4.pkl", 'rb') as f:
    base_2_4 = pickle.load(f)

with open("cifar10/N[100]_R[1000]_E[5]_iid[1]_PR[1]_F[1]_LR[0.1]_LD[0.998]_B[3]_RB[0]_S[0]_hetero_3.pkl", 'rb') as f:
    base_3_3 = pickle.load(f)

with open("cifar10/N[100]_R[1000]_E[5]_iid[1]_PR[1]_F[1]_LR[0.1]_LD[0.998]_B[3]_RB[0]_S[0]_hetero_4.pkl", 'rb') as f:
    base_3_4 = pickle.load(f)

x = [(i+1) * 5 for i in range(len(main_3)-10)]

mv_multi_3 = mv_average_10(main_3)
mv_base_0_3 = mv_average_10(base_0_3)
mv_base_1_3 = mv_average_10(base_1_3)
mv_base_2_3 = mv_average_10(base_2_3)
mv_base_3_3 = mv_average_10(base_3_3)

mv_multi_4 = mv_average_10(main_4)
mv_base_0_4 = mv_average_10(base_0_4)
mv_base_1_4 = mv_average_10(base_1_4)
mv_base_2_4 = mv_average_10(base_2_4)
mv_base_3_4 = mv_average_10(base_3_4)

plt.figure(dpi=120)
plt.grid(b=True, which='major', axis='both')
plt.title("Compare with Naive Baselines - HeteroFL CIFAR10")
plt.plot(x, mv_multi_3, label = 'HeteroFL')
plt.plot(x, mv_base_0_3, label = 'a-100%')
plt.plot(x, mv_base_1_3, label = 'b-75%')
plt.plot(x, mv_base_2_3, label = 'c-50%')
plt.plot(x, mv_base_3_3, label = 'd-25%')

print(mv_multi_3[-1])
print(mv_base_0_3[-1])
print(mv_base_1_3[-1])
print(mv_base_2_3[-1])
print(mv_base_3_3[-1])
print('-'*10)
print(mv_multi_4[-1])
print(mv_base_0_4[-1])
print(mv_base_1_4[-1])
print(mv_base_2_4[-1])
print(mv_base_3_4[-1])
print('-'*10)
print(round((mv_multi_3[-1]+mv_multi_4[-1])/2,4))
print(round((mv_base_0_3[-1]+mv_base_0_4[-1])/2,4))
print(round((mv_base_1_3[-1]+mv_base_1_4[-1])/2,4))
print(round((mv_base_2_3[-1]+mv_base_2_4[-1])/2,4))
print(round((mv_base_3_3[-1]+mv_base_3_4[-1])/2,4))

plt.xlabel("Round") 
plt.legend(loc='lower right')
plt.show()
# Out:
# 0.8309
# 0.8174
# 0.8429
# 0.8406
# 0.8132
# ----------
# 0.8324
# 0.818
# 0.8422
# 0.8396
# 0.8168
# ----------
# 0.8317
# 0.8177
# 0.8425
# 0.8401
# 0.815

# %%
import matplotlib.pyplot as plt
import pickle


with open("cifar100/N[100]_R[1000]_E[5]_iid[1]_PR[1]_F[1]_LR[0.1]_LD[0.998]_B[-1]_RB[0]_S[1]_hetero_3.pkl", 'rb') as f:
    main_3 = pickle.load(f)

with open("cifar100/N[100]_R[1000]_E[5]_iid[1]_PR[1]_F[1]_LR[0.1]_LD[0.998]_B[-1]_RB[0]_S[1]_hetero_4.pkl", 'rb') as f:
    main_4 = pickle.load(f)

with open("cifar100/N[100]_R[1000]_E[5]_iid[1]_PR[1]_F[1]_LR[0.1]_LD[0.998]_B[0]_RB[0]_S[0]_hetero_3.pkl", 'rb') as f:
    base_0_3 = pickle.load(f)

with open("cifar100/N[100]_R[1000]_E[5]_iid[1]_PR[1]_F[1]_LR[0.1]_LD[0.998]_B[0]_RB[0]_S[0]_hetero_4.pkl", 'rb') as f:
    base_0_4 = pickle.load(f)

with open("cifar100/N[100]_R[1000]_E[5]_iid[1]_PR[1]_F[1]_LR[0.1]_LD[0.998]_B[1]_RB[0]_S[0]_hetero_3.pkl", 'rb') as f:
    base_1_3 = pickle.load(f)

with open("cifar100/N[100]_R[1000]_E[5]_iid[1]_PR[1]_F[1]_LR[0.1]_LD[0.998]_B[1]_RB[0]_S[0]_hetero_4.pkl", 'rb') as f:
    base_1_4 = pickle.load(f)

with open("cifar100/N[100]_R[1000]_E[5]_iid[1]_PR[1]_F[1]_LR[0.1]_LD[0.998]_B[2]_RB[0]_S[0]_hetero_3.pkl", 'rb') as f:
    base_2_3 = pickle.load(f)

with open("cifar100/N[100]_R[1000]_E[5]_iid[1]_PR[1]_F[1]_LR[0.1]_LD[0.998]_B[2]_RB[0]_S[0]_hetero_4.pkl", 'rb') as f:
    base_2_4 = pickle.load(f)

with open("cifar100/N[100]_R[1000]_E[5]_iid[1]_PR[1]_F[1]_LR[0.1]_LD[0.998]_B[3]_RB[0]_S[0]_hetero_3.pkl", 'rb') as f:
    base_3_3 = pickle.load(f)

with open("cifar100/N[100]_R[1000]_E[5]_iid[1]_PR[1]_F[1]_LR[0.1]_LD[0.998]_B[3]_RB[0]_S[0]_hetero_4.pkl", 'rb') as f:
    base_3_4 = pickle.load(f)

x = [(i+1) * 5 for i in range(len(main_3)-10)]

mv_multi_3 = mv_average_10(main_3)
mv_base_0_3 = mv_average_10(base_0_3)
mv_base_1_3 = mv_average_10(base_1_3)
mv_base_2_3 = mv_average_10(base_2_3)
mv_base_3_3 = mv_average_10(base_3_3)

mv_multi_4 = mv_average_10(main_4)
mv_base_0_4 = mv_average_10(base_0_4)
mv_base_1_4 = mv_average_10(base_1_4)
mv_base_2_4 = mv_average_10(base_2_4)
mv_base_3_4 = mv_average_10(base_3_4)

plt.figure(dpi=120)
plt.grid(b=True, which='major', axis='both')
plt.title("Compare with Naive Baselines - HeteroFL CIFAR100")
plt.plot(x, mv_multi_3, label = 'HeteroFL')
plt.plot(x, mv_base_0_3, label = 'a-100%')
plt.plot(x, mv_base_1_3, label = 'b-75%')
plt.plot(x, mv_base_2_3, label = 'c-50%')
plt.plot(x, mv_base_3_3, label = 'd-25%')

print(mv_multi_3[-1])
print(mv_base_0_3[-1])
print(mv_base_1_3[-1])
print(mv_base_2_3[-1])
print(mv_base_3_3[-1])
print('-'*10)
print(mv_multi_4[-1])
print(mv_base_0_4[-1])
print(mv_base_1_4[-1])
print(mv_base_2_4[-1])
print(mv_base_3_4[-1])
print('-'*10)
print(round((mv_multi_3[-1]+mv_multi_4[-1])/2,4))
print(round((mv_base_0_3[-1]+mv_base_0_4[-1])/2,4))
print(round((mv_base_1_3[-1]+mv_base_1_4[-1])/2,4))
print(round((mv_base_2_3[-1]+mv_base_2_4[-1])/2,4))
print(round((mv_base_3_3[-1]+mv_base_3_4[-1])/2,4))

plt.xlabel("Round") 
plt.legend(loc='lower right')
plt.show()
# Out:
# 0.5662
# 0.6391
# 0.6556
# 0.6117
# 0.5148
# ----------
# 0.5727
# 0.6411
# 0.661
# 0.6193
# 0.5163
# ----------
# 0.5695
# 0.6401
# 0.6583
# 0.6155
# 0.5155

# %%
import matplotlib.pyplot as plt
import pickle


with open("tiny-imagenet/N[100]_R[1000]_E[5]_iid[1]_PR[1]_F[1]_LR[0.1]_LD[0.998]_B[-1]_RB[0]_S[1]_hetero_3.pkl", 'rb') as f:
    main_3 = pickle.load(f)

with open("tiny-imagenet/N[100]_R[1000]_E[5]_iid[1]_PR[1]_F[1]_LR[0.1]_LD[0.998]_B[-1]_RB[0]_S[1]_hetero_4.pkl", 'rb') as f:
    main_4 = pickle.load(f)

with open("tiny-imagenet/N[100]_R[1000]_E[5]_iid[1]_PR[1]_F[1]_LR[0.1]_LD[0.998]_B[0]_RB[0]_S[0]_hetero_3.pkl", 'rb') as f:
    base_0_3 = pickle.load(f)

with open("tiny-imagenet/N[100]_R[1000]_E[5]_iid[1]_PR[1]_F[1]_LR[0.1]_LD[0.998]_B[0]_RB[0]_S[0]_hetero_4.pkl", 'rb') as f:
    base_0_4 = pickle.load(f)

with open("tiny-imagenet/N[100]_R[1000]_E[5]_iid[1]_PR[1]_F[1]_LR[0.1]_LD[0.998]_B[1]_RB[0]_S[0]_hetero_3.pkl", 'rb') as f:
    base_1_3 = pickle.load(f)

with open("tiny-imagenet/N[100]_R[1000]_E[5]_iid[1]_PR[1]_F[1]_LR[0.1]_LD[0.998]_B[1]_RB[0]_S[0]_hetero_4.pkl", 'rb') as f:
    base_1_4 = pickle.load(f)

with open("tiny-imagenet/N[100]_R[1000]_E[5]_iid[1]_PR[1]_F[1]_LR[0.1]_LD[0.998]_B[2]_RB[0]_S[0]_hetero_3.pkl", 'rb') as f:
    base_2_3 = pickle.load(f)

with open("tiny-imagenet/N[100]_R[1000]_E[5]_iid[1]_PR[1]_F[1]_LR[0.1]_LD[0.998]_B[2]_RB[0]_S[0]_hetero_4.pkl", 'rb') as f:
    base_2_4 = pickle.load(f)

with open("tiny-imagenet/N[100]_R[1000]_E[5]_iid[1]_PR[1]_F[1]_LR[0.1]_LD[0.998]_B[3]_RB[0]_S[0]_hetero_3.pkl", 'rb') as f:
    base_3_3 = pickle.load(f)

with open("tiny-imagenet/N[100]_R[1000]_E[5]_iid[1]_PR[1]_F[1]_LR[0.1]_LD[0.998]_B[3]_RB[0]_S[0]_hetero_4.pkl", 'rb') as f:
    base_3_4 = pickle.load(f)

x = [(i+1) * 5 for i in range(len(main_3)-10)]

mv_multi_3 = mv_average_10(main_3)
mv_base_0_3 = mv_average_10(base_0_3)
mv_base_1_3 = mv_average_10(base_1_3)
mv_base_2_3 = mv_average_10(base_2_3)
mv_base_3_3 = mv_average_10(base_3_3)

mv_multi_4 = mv_average_10(main_4)
mv_base_0_4 = mv_average_10(base_0_4)
mv_base_1_4 = mv_average_10(base_1_4)
mv_base_2_4 = mv_average_10(base_2_4)
mv_base_3_4 = mv_average_10(base_3_4)

plt.figure(dpi=120)
plt.grid(b=True, which='major', axis='both')
plt.title("Compare with Naive Baselines - HeteroFL tiny-imagenet")
plt.plot(x, mv_multi_3, label = 'HeteroFL')
plt.plot(x, mv_base_0_3, label = 'a-100%')
plt.plot(x, mv_base_1_3, label = 'b-75%')
plt.plot(x, mv_base_2_3, label = 'c-50%')
plt.plot(x, mv_base_3_3, label = 'd-25%')

print(mv_multi_3[-1])
print(mv_base_0_3[-1])
print(mv_base_1_3[-1])
print(mv_base_2_3[-1])
print(mv_base_3_3[-1])
print('-'*10)
print(mv_multi_4[-1])
print(mv_base_0_4[-1])
print(mv_base_1_4[-1])
print(mv_base_2_4[-1])
print(mv_base_3_4[-1])
print('-'*10)
print(round((mv_multi_3[-1]+mv_multi_4[-1])/2,4))
print(round((mv_base_0_3[-1]+mv_base_0_4[-1])/2,4))
print(round((mv_base_1_3[-1]+mv_base_1_4[-1])/2,4))
print(round((mv_base_2_3[-1]+mv_base_2_4[-1])/2,4))
print(round((mv_base_3_3[-1]+mv_base_3_4[-1])/2,4))

plt.xlabel("Round") 
plt.legend(loc='lower right')
plt.show()
# Out:
# 0.3027
# 0.3956
# 0.3961
# 0.3425
# 0.2569
# ----------
# 0.3028
# 0.3958
# 0.391
# 0.338
# 0.2606
# ----------
# 0.3028
# 0.3957
# 0.3936
# 0.3403
# 0.2588
