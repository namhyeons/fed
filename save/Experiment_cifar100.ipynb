# %%
def mv_average_10(lst):
    mv_lst = []
    for i in range(len(lst)-10):
        mv_lst.append(round(sum(lst[i:i+10]) / 10, 4))
    return mv_lst

# %%
import matplotlib.pyplot as plt
import pickle

with open("cifar100/N[100]_iid[1]_K[0]_F[0]_Fe[0]_B[0.03]_P[0.25,0.25,0.25,0.25]_decay[0.998]_R[300]_norm[bn]_RB[0]_no[-1]_FR[0.1]_Ba[-1]_main_3.pkl", 'rb') as f:
    main_3 = pickle.load(f)

with open("cifar100/N[100]_iid[1]_K[0]_F[0]_Fe[0]_B[0.03]_P[0.25,0.25,0.25,0.25]_decay[0.998]_R[300]_norm[bn]_RB[0]_no[-1]_FR[0.1]_Ba[-1]_main_4.pkl", 'rb') as f:
    main_4 = pickle.load(f)

with open("cifar100/N[100]_R[1000]_iid[1]_K[0]_F[0]_B[0]_no[bn]_base_3.pkl", 'rb') as f:
    base_0_3 = pickle.load(f)

with open("cifar100/N[100]_R[1000]_iid[1]_K[0]_F[0]_B[0]_no[bn]_base_4.pkl", 'rb') as f:
    base_0_4 = pickle.load(f)

with open("cifar100/N[100]_R[1000]_iid[1]_K[0]_F[0]_B[1]_no[bn]_base_3.pkl", 'rb') as f:
    base_1_3 = pickle.load(f)

with open("cifar100/N[100]_R[1000]_iid[1]_K[0]_F[0]_B[1]_no[bn]_base_4.pkl", 'rb') as f:
    base_1_4 = pickle.load(f)

with open("cifar100/N[100]_R[1000]_iid[1]_K[0]_F[0]_B[2]_no[bn]_base_3.pkl", 'rb') as f:
    base_2_3 = pickle.load(f)

with open("cifar100/N[100]_R[1000]_iid[1]_K[0]_F[0]_B[2]_no[bn]_base_4.pkl", 'rb') as f:
    base_2_4 = pickle.load(f)

with open("cifar100/N[100]_R[1000]_iid[1]_K[0]_F[0]_B[3]_no[bn]_base_3.pkl", 'rb') as f:
    base_3_3 = pickle.load(f)

with open("cifar100/N[100]_R[1000]_iid[1]_K[0]_F[0]_B[3]_no[bn]_base_4.pkl", 'rb') as f:
    base_3_4 = pickle.load(f)

x = [(i+1) * 5 for i in range(len(base_0_3[0]['single'])-10)]


mv_multi_3 = mv_average_10(main_3[0]['multi'])
mv_base_0_3 = mv_average_10(base_0_3[0]['multi'])
mv_base_1_3 = mv_average_10(base_1_3[0]['multi'])
mv_base_2_3 = mv_average_10(base_2_3[0]['multi'])
mv_base_3_3 = mv_average_10(base_3_3[0]['multi'])

mv_multi_4 = mv_average_10(main_4[0]['multi'])
mv_base_0_4 = mv_average_10(base_0_4[0]['multi'])
mv_base_1_4 = mv_average_10(base_1_4[0]['multi'])
mv_base_2_4 = mv_average_10(base_2_4[0]['multi'])
mv_base_3_4 = mv_average_10(base_3_4[0]['multi'])



plt.figure(dpi=120)
plt.grid(b=True, which='major', axis='both')
plt.title("Compare with Naive Baselines - Self-FL(FedAvg)")
plt.plot(x, mv_multi_3, label = 'Self-FL')
plt.plot(x, mv_base_0_3, label = 'a-100%')
plt.plot(x, mv_base_1_3, label = 'b-75%')
plt.plot(x, mv_base_2_3, label = 'c-50%')
plt.plot(x, mv_base_3_3, label = 'd-25%')


print(mv_multi_3[-1])
print(mv_base_0_3[-1])
print(mv_base_1_3[-1])
print(mv_base_2_3[-1])
print(mv_base_3_3[-1])
print("------------------")
print(mv_multi_4[-1])
print(mv_base_0_4[-1])
print(mv_base_1_4[-1])
print(mv_base_2_4[-1])
print(mv_base_3_4[-1])
print("------------------")
print(round((mv_multi_3[-1]+mv_multi_4[-1])/2,4))
print(round((mv_base_0_3[-1] + mv_base_0_4[-1])/2,4))
print(round((mv_base_1_3[-1] + mv_base_1_4[-1])/2,4))
print(round((mv_base_2_3[-1] + mv_base_2_4[-1])/2,4))
print(round((mv_base_3_3[-1] + mv_base_3_4[-1])/2,4))


plt.xlabel("Round") 
plt.legend(loc='lower right')
plt.show()
# Out:
# 0.7239
# 0.6652
# 0.7005
# 0.6774
# 0.5891
# ------------------
# 0.7214
# 0.6649
# 0.7005
# 0.6786
# 0.5914
# ------------------
# 0.7227
# 0.6651
# 0.7005
# 0.678
# 0.5902

# %%
import matplotlib.pyplot as plt
import pickle

with open("cifar100/N[100]_iid[1]_K[1]_F[1]_Fe[0]_B[0.03]_P[0.25,0.25,0.25,0.25]_decay[0.998]_R[300]_norm[bn]_RB[0]_no[-1]_FR[0.1]_Ba[-1]_main_3.pkl", 'rb') as f:
    main_3 = pickle.load(f)

with open("cifar100/N[100]_iid[1]_K[1]_F[1]_Fe[0]_B[0.03]_P[0.25,0.25,0.25,0.25]_decay[0.998]_R[300]_norm[bn]_RB[0]_no[-1]_FR[0.1]_Ba[-1]_main_4.pkl", 'rb') as f:
    main_4 = pickle.load(f)

with open("cifar100/N[100]_R[1000]_iid[1]_K[1]_F[1]_B[0]_no[bn]_base_3.pkl", 'rb') as f:
    base_0_3 = pickle.load(f)

with open("cifar100/N[100]_R[1000]_iid[1]_K[1]_F[1]_B[0]_no[bn]_base_4.pkl", 'rb') as f:
    base_0_4 = pickle.load(f)

with open("cifar100/N[100]_R[1000]_iid[1]_K[1]_F[1]_B[1]_no[bn]_base_3.pkl", 'rb') as f:
    base_1_3 = pickle.load(f)

with open("cifar100/N[100]_R[1000]_iid[1]_K[1]_F[1]_B[1]_no[bn]_base_4.pkl", 'rb') as f:
    base_1_4 = pickle.load(f)

with open("cifar100/N[100]_R[1000]_iid[1]_K[1]_F[1]_B[2]_no[bn]_base_3.pkl", 'rb') as f:
    base_2_3 = pickle.load(f)

with open("cifar100/N[100]_R[1000]_iid[1]_K[1]_F[1]_B[2]_no[bn]_base_4.pkl", 'rb') as f:
    base_2_4 = pickle.load(f)

with open("cifar100/N[100]_R[1000]_iid[1]_K[1]_F[1]_B[3]_no[bn]_base_3.pkl", 'rb') as f:
    base_3_3 = pickle.load(f)

with open("cifar100/N[100]_R[1000]_iid[1]_K[1]_F[1]_B[3]_no[bn]_base_4.pkl", 'rb') as f:
    base_3_4 = pickle.load(f)

x = [(i+1) * 5 for i in range(len(base_0_3[0]['single'])-10)]


mv_multi_3 = mv_average_10(main_3[0]['multi'])
mv_base_0_3 = mv_average_10(base_0_3[0]['multi'])
mv_base_1_3 = mv_average_10(base_1_3[0]['multi'])
mv_base_2_3 = mv_average_10(base_2_3[0]['multi'])
mv_base_3_3 = mv_average_10(base_3_3[0]['multi'])

mv_multi_4 = mv_average_10(main_4[0]['multi'])
mv_base_0_4 = mv_average_10(base_0_4[0]['multi'])
mv_base_1_4 = mv_average_10(base_1_4[0]['multi'])
mv_base_2_4 = mv_average_10(base_2_4[0]['multi'])
mv_base_3_4 = mv_average_10(base_3_4[0]['multi'])



plt.figure(dpi=120)
plt.grid(b=True, which='major', axis='both')
plt.title("Compare with Naive Baselines - Self-FL")
plt.plot(x, mv_multi_3, label = 'Self-FL')
plt.plot(x, mv_base_0_3, label = 'a-100%')
plt.plot(x, mv_base_1_3, label = 'b-75%')
plt.plot(x, mv_base_2_3, label = 'c-50%')
plt.plot(x, mv_base_3_3, label = 'd-25%')


print(mv_multi_3[-1])
print(mv_base_0_3[-1])
print(mv_base_1_3[-1])
print(mv_base_2_3[-1])
print(mv_base_3_3[-1])
print("------------------")
print(mv_multi_4[-1])
print(mv_base_0_4[-1])
print(mv_base_1_4[-1])
print(mv_base_2_4[-1])
print(mv_base_3_4[-1])
print("------------------")
print(round((mv_multi_3[-1]+mv_multi_4[-1])/2,4))
print(round((mv_base_0_3[-1] + mv_base_0_4[-1])/2,4))
print(round((mv_base_1_3[-1] + mv_base_1_4[-1])/2,4))
print(round((mv_base_2_3[-1] + mv_base_2_4[-1])/2,4))
print(round((mv_base_3_3[-1] + mv_base_3_4[-1])/2,4))


plt.xlabel("Round") 
plt.legend(loc='lower right')
plt.show()
# Out:
# 0.7632
# 0.6945
# 0.7401
# 0.7086
# 0.6119
# ------------------
# 0.7642
# 0.6991
# 0.7386
# 0.7166
# 0.6081
# ------------------
# 0.7637
# 0.6968
# 0.7393
# 0.7126
# 0.61

# %%
import matplotlib.pyplot as plt
import pickle


with open("cifar100/N[100]_iid[1]_K[1]_F[1]_Fe[0]_B[0.03]_P[0.25,0.25,0.25,0.25]_decay[0.998]_R[300]_norm[bn]_RB[0]_no[-1]_FR[0.1]_Ba[-1]_main_3.pkl", 'rb') as f:
    main_3 = pickle.load(f)

with open("cifar100/N[100]_iid[1]_K[1]_F[1]_Fe[0]_B[0.03]_P[0.25,0.25,0.25,0.25]_decay[0.998]_R[300]_norm[bn]_RB[0]_no[-1]_FR[0.1]_Ba[-1]_main_4.pkl", 'rb') as f:
    main_4 = pickle.load(f)

x = [(i+1) * 5 for i in range(len(main_3[0]['single'])-10)]

plt.figure(dpi=120)
plt.grid(b=True, which='major', axis='both')
plt.title('with KD - iid')

mv_multi_3 = mv_average_10(main_3[0]['multi'])
mv_single_1_3 = mv_average_10([x[0] for x in main_3[0]['single']])
mv_single_2_3 = mv_average_10([x[1] for x in main_3[0]['single']])
mv_single_3_3 = mv_average_10([x[2] for x in main_3[0]['single']])
mv_single_4_3 = mv_average_10([x[3] for x in main_3[0]['single']])

mv_multi_4 = mv_average_10(main_4[0]['multi'])
mv_single_1_4 = mv_average_10([x[0] for x in main_4[0]['single']])
mv_single_2_4 = mv_average_10([x[1] for x in main_4[0]['single']])
mv_single_3_4 = mv_average_10([x[2] for x in main_4[0]['single']])
mv_single_4_4 = mv_average_10([x[3] for x in main_4[0]['single']])

plt.plot(x, mv_multi_3, label = 'Self-FL')
plt.plot(x, mv_single_1_3, label='1/4 Classifier')
plt.plot(x, mv_single_2_3, label='2/4 Classifier')
plt.plot(x, mv_single_3_3, label='3/4 Classifier')
plt.plot(x, mv_single_4_3, label='4/4 Classifier')


print(mv_single_1_3[-1])
print(mv_single_2_3[-1])
print(mv_single_3_3[-1])
print(mv_single_4_3[-1])
print(mv_multi_3[-1])
print('-'*10)
print(mv_single_1_4[-1])
print(mv_single_2_4[-1])
print(mv_single_3_4[-1])
print(mv_single_4_4[-1])
print(mv_multi_4[-1])
print('-'*10)

print(round((mv_single_1_3[-1] + mv_single_1_4[-1])/2,4))
print(round((mv_single_2_3[-1] + mv_single_2_4[-1])/2,4))
print(round((mv_single_3_3[-1] + mv_single_3_4[-1])/2,4))
print(round((mv_single_4_3[-1] + mv_single_4_4[-1])/2,4))
print(round((mv_multi_3[-1] + mv_multi_4[-1])/2,4))

plt.xlabel("Round") 
plt.legend(loc='lower right')
plt.show()
# Out:
# 0.7178
# 0.736
# 0.7358
# 0.7359
# 0.7632
# ----------
# 0.7215
# 0.7361
# 0.7339
# 0.7335
# 0.7642
# ----------
# 0.7197
# 0.736
# 0.7349
# 0.7347
# 0.7637

# %%
import matplotlib.pyplot as plt
import pickle


with open("cifar100/N[100]_iid[1]_K[0]_F[1]_Fe[0]_B[0.03]_P[0.25,0.25,0.25,0.25]_decay[0.998]_R[300]_norm[bn]_RB[0]_no[-1]_FR[0.1]_Ba[-1]_main_3.pkl", 'rb') as f:
    main_3 = pickle.load(f)

with open("cifar100/N[100]_iid[1]_K[0]_F[1]_Fe[0]_B[0.03]_P[0.25,0.25,0.25,0.25]_decay[0.998]_R[300]_norm[bn]_RB[0]_no[-1]_FR[0.1]_Ba[-1]_main_4.pkl", 'rb') as f:
    main_4 = pickle.load(f)

x = [(i+1) * 5 for i in range(len(main_3[0]['single'])-10)]

plt.figure(dpi=120)
plt.grid(b=True, which='major', axis='both')
plt.title('without KD - iid')

mv_multi_3 = mv_average_10(main_3[0]['multi'])
mv_single_1_3 = mv_average_10([x[0] for x in main_3[0]['single']])
mv_single_2_3 = mv_average_10([x[1] for x in main_3[0]['single']])
mv_single_3_3 = mv_average_10([x[2] for x in main_3[0]['single']])
mv_single_4_3 = mv_average_10([x[3] for x in main_3[0]['single']])

mv_multi_4 = mv_average_10(main_4[0]['multi'])
mv_single_1_4 = mv_average_10([x[0] for x in main_4[0]['single']])
mv_single_2_4 = mv_average_10([x[1] for x in main_4[0]['single']])
mv_single_3_4 = mv_average_10([x[2] for x in main_4[0]['single']])
mv_single_4_4 = mv_average_10([x[3] for x in main_4[0]['single']])

plt.plot(x, mv_multi_3, label = 'Self-FL')
plt.plot(x, mv_single_1_3, label='1/4 Classifier')
plt.plot(x, mv_single_2_3, label='2/4 Classifier')
plt.plot(x, mv_single_3_3, label='3/4 Classifier')
plt.plot(x, mv_single_4_3, label='4/4 Classifier')


print(mv_single_1_3[-1])
print(mv_single_2_3[-1])
print(mv_single_3_3[-1])
print(mv_single_4_3[-1])
print(mv_multi_3[-1])
print('-'*10)
print(mv_single_1_4[-1])
print(mv_single_2_4[-1])
print(mv_single_3_4[-1])
print(mv_single_4_4[-1])
print(mv_multi_4[-1])
print('-'*10)

print(round((mv_single_1_3[-1] + mv_single_1_4[-1])/2,4))
print(round((mv_single_2_3[-1] + mv_single_2_4[-1])/2,4))
print(round((mv_single_3_3[-1] + mv_single_3_4[-1])/2,4))
print(round((mv_single_4_3[-1] + mv_single_4_4[-1])/2,4))
print(round((mv_multi_3[-1] + mv_multi_4[-1])/2,4))

plt.xlabel("Round") 
plt.legend(loc='lower right')
plt.show()
# Out:
# 0.6932
# 0.6948
# 0.6828
# 0.6808
# 0.7395
# ----------
# 0.6953
# 0.6923
# 0.6814
# 0.68
# 0.7409
# ----------
# 0.6943
# 0.6935
# 0.6821
# 0.6804
# 0.7402

# %%
import matplotlib.pyplot as plt
import pickle


with open("cifar100/N[100]_iid[0]_K[1]_F[1]_Fe[0]_B[0.03]_P[0.25,0.25,0.25,0.25]_decay[0.998]_R[300]_norm[bn]_RB[0]_no[-1]_FR[0.1]_Ba[-1]_main_3.pkl", 'rb') as f:
    main_3 = pickle.load(f)

with open("cifar100/N[100]_iid[0]_K[1]_F[1]_Fe[0]_B[0.03]_P[0.25,0.25,0.25,0.25]_decay[0.998]_R[300]_norm[bn]_RB[0]_no[-1]_FR[0.1]_Ba[-1]_main_4.pkl", 'rb') as f:
    main_4 = pickle.load(f)

x = [(i+1) * 5 for i in range(len(main_3[0]['single'])-10)]

plt.figure(dpi=120)
plt.grid(b=True, which='major', axis='both')
plt.title('with KD - noniid')

mv_multi_3 = mv_average_10(main_3[0]['multi'])
mv_single_1_3 = mv_average_10([x[0] for x in main_3[0]['single']])
mv_single_2_3 = mv_average_10([x[1] for x in main_3[0]['single']])
mv_single_3_3 = mv_average_10([x[2] for x in main_3[0]['single']])
mv_single_4_3 = mv_average_10([x[3] for x in main_3[0]['single']])

mv_multi_4 = mv_average_10(main_4[0]['multi'])
mv_single_1_4 = mv_average_10([x[0] for x in main_4[0]['single']])
mv_single_2_4 = mv_average_10([x[1] for x in main_4[0]['single']])
mv_single_3_4 = mv_average_10([x[2] for x in main_4[0]['single']])
mv_single_4_4 = mv_average_10([x[3] for x in main_4[0]['single']])

plt.plot(x, mv_multi_3, label = 'Self-FL')
plt.plot(x, mv_single_1_3, label='1/4 Classifier')
plt.plot(x, mv_single_2_3, label='2/4 Classifier')
plt.plot(x, mv_single_3_3, label='3/4 Classifier')
plt.plot(x, mv_single_4_3, label='4/4 Classifier')


print(mv_single_1_3[-1])
print(mv_single_2_3[-1])
print(mv_single_3_3[-1])
print(mv_single_4_3[-1])
print(mv_multi_3[-1])
print('-'*10)
print(mv_single_1_4[-1])
print(mv_single_2_4[-1])
print(mv_single_3_4[-1])
print(mv_single_4_4[-1])
print(mv_multi_4[-1])
print('-'*10)

print(round((mv_single_1_3[-1] + mv_single_1_4[-1])/2,4))
print(round((mv_single_2_3[-1] + mv_single_2_4[-1])/2,4))
print(round((mv_single_3_3[-1] + mv_single_3_4[-1])/2,4))
print(round((mv_single_4_3[-1] + mv_single_4_4[-1])/2,4))
print(round((mv_multi_3[-1] + mv_multi_4[-1])/2,4))

plt.xlabel("Round") 
plt.legend(loc='lower right')
plt.show()
# Out:
# 0.7006
# 0.7133
# 0.7195
# 0.7156
# 0.7459
# ----------
# 0.6969
# 0.7108
# 0.7171
# 0.7174
# 0.743
# ----------
# 0.6987
# 0.7121
# 0.7183
# 0.7165
# 0.7445

# %%
import matplotlib.pyplot as plt
import pickle


with open("cifar100/N[100]_iid[0]_K[0]_F[1]_Fe[0]_B[0.03]_P[0.25,0.25,0.25,0.25]_decay[0.998]_R[300]_norm[bn]_RB[0]_no[-1]_FR[0.1]_Ba[-1]_main_3.pkl", 'rb') as f:
    main_3 = pickle.load(f)

with open("cifar100/N[100]_iid[0]_K[0]_F[1]_Fe[0]_B[0.03]_P[0.25,0.25,0.25,0.25]_decay[0.998]_R[300]_norm[bn]_RB[0]_no[-1]_FR[0.1]_Ba[-1]_main_4.pkl", 'rb') as f:
    main_4 = pickle.load(f)

x = [(i+1) * 5 for i in range(len(main_3[0]['single'])-10)]

plt.figure(dpi=120)
plt.grid(b=True, which='major', axis='both')
plt.title('without KD - noniid')

mv_multi_3 = mv_average_10(main_3[0]['multi'])
mv_single_1_3 = mv_average_10([x[0] for x in main_3[0]['single']])
mv_single_2_3 = mv_average_10([x[1] for x in main_3[0]['single']])
mv_single_3_3 = mv_average_10([x[2] for x in main_3[0]['single']])
mv_single_4_3 = mv_average_10([x[3] for x in main_3[0]['single']])

mv_multi_4 = mv_average_10(main_4[0]['multi'])
mv_single_1_4 = mv_average_10([x[0] for x in main_4[0]['single']])
mv_single_2_4 = mv_average_10([x[1] for x in main_4[0]['single']])
mv_single_3_4 = mv_average_10([x[2] for x in main_4[0]['single']])
mv_single_4_4 = mv_average_10([x[3] for x in main_4[0]['single']])

plt.plot(x, mv_multi_3, label = 'Self-FL')
plt.plot(x, mv_single_1_3, label='1/4 Classifier')
plt.plot(x, mv_single_2_3, label='2/4 Classifier')
plt.plot(x, mv_single_3_3, label='3/4 Classifier')
plt.plot(x, mv_single_4_3, label='4/4 Classifier')


print(mv_single_1_3[-1])
print(mv_single_2_3[-1])
print(mv_single_3_3[-1])
print(mv_single_4_3[-1])
print(mv_multi_3[-1])
print('-'*10)
print(mv_single_1_4[-1])
print(mv_single_2_4[-1])
print(mv_single_3_4[-1])
print(mv_single_4_4[-1])
print(mv_multi_4[-1])
print('-'*10)

print(round((mv_single_1_3[-1] + mv_single_1_4[-1])/2,4))
print(round((mv_single_2_3[-1] + mv_single_2_4[-1])/2,4))
print(round((mv_single_3_3[-1] + mv_single_3_4[-1])/2,4))
print(round((mv_single_4_3[-1] + mv_single_4_4[-1])/2,4))
print(round((mv_multi_3[-1] + mv_multi_4[-1])/2,4))

plt.xlabel("Round") 
plt.legend(loc='lower right')
plt.show()
# Out:
# 0.6692
# 0.6703
# 0.6757
# 0.6694
# 0.7272
# ----------
# 0.6661
# 0.6814
# 0.6738
# 0.6703
# 0.7265
# ----------
# 0.6677
# 0.6759
# 0.6747
# 0.6699
# 0.7268

# %%
import matplotlib.pyplot as plt
import pickle


with open("cifar100/N[100]_iid[1]_K[1]_F[1]_Fe[0]_B[0.03]_P[0.25,0.25,0.25,0.25]_decay[0.998]_R[300]_norm[bn]_RB[1]_no[-1]_FR[0.1]_Ba[-1]_main_3.pkl", 'rb') as f:
    main_3 = pickle.load(f)

with open("cifar100/N[100]_iid[1]_K[1]_F[1]_Fe[0]_B[0.03]_P[0.25,0.25,0.25,0.25]_decay[0.998]_R[300]_norm[bn]_RB[1]_no[-1]_FR[0.1]_Ba[-1]_main_4.pkl", 'rb') as f:
    main_4 = pickle.load(f)

x = [(i+1) * 5 for i in range(len(main_3[0]['single'])-10)]

plt.figure(dpi=120)
plt.grid(b=True, which='major', axis='both')
plt.title('Random Branch w/ KD')

mv_multi_3 = mv_average_10(main_3[0]['multi'])
mv_single_1_3 = mv_average_10([x[0] for x in main_3[0]['single']])
mv_single_2_3 = mv_average_10([x[1] for x in main_3[0]['single']])
mv_single_3_3 = mv_average_10([x[2] for x in main_3[0]['single']])
mv_single_4_3 = mv_average_10([x[3] for x in main_3[0]['single']])

mv_multi_4 = mv_average_10(main_4[0]['multi'])
mv_single_1_4 = mv_average_10([x[0] for x in main_4[0]['single']])
mv_single_2_4 = mv_average_10([x[1] for x in main_4[0]['single']])
mv_single_3_4 = mv_average_10([x[2] for x in main_4[0]['single']])
mv_single_4_4 = mv_average_10([x[3] for x in main_4[0]['single']])

plt.plot(x, mv_multi_3, label = 'Self-FL')
plt.plot(x, mv_single_1_3, label='1/4 Classifier')
plt.plot(x, mv_single_2_3, label='2/4 Classifier')
plt.plot(x, mv_single_3_3, label='3/4 Classifier')
plt.plot(x, mv_single_4_3, label='4/4 Classifier')


print(mv_single_1_3[-1])
print(mv_single_2_3[-1])
print(mv_single_3_3[-1])
print(mv_single_4_3[-1])
print(mv_multi_3[-1])
print('-'*10)
print(mv_single_1_4[-1])
print(mv_single_2_4[-1])
print(mv_single_3_4[-1])
print(mv_single_4_4[-1])
print(mv_multi_4[-1])
print('-'*10)

print(round((mv_single_1_3[-1] + mv_single_1_4[-1])/2,4))
print(round((mv_single_2_3[-1] + mv_single_2_4[-1])/2,4))
print(round((mv_single_3_3[-1] + mv_single_3_4[-1])/2,4))
print(round((mv_single_4_3[-1] + mv_single_4_4[-1])/2,4))
print(round((mv_multi_3[-1] + mv_multi_4[-1])/2,4))

plt.xlabel("Round") 
plt.legend(loc='lower right')
plt.show()
# Out:
# 0.7243
# 0.7477
# 0.7576
# 0.7582
# 0.7729
# ----------
# 0.7236
# 0.7486
# 0.7563
# 0.7569
# 0.7748
# ----------
# 0.724
# 0.7482
# 0.757
# 0.7575
# 0.7739

# %%
import matplotlib.pyplot as plt
import pickle


with open("cifar100/N[100]_iid[1]_K[0]_F[1]_Fe[0]_B[0.03]_P[0.25,0.25,0.25,0.25]_decay[0.998]_R[300]_norm[bn]_RB[1]_no[-1]_FR[0.1]_Ba[-1]_main_3.pkl", 'rb') as f:
    main_3 = pickle.load(f)

with open("cifar100/N[100]_iid[1]_K[0]_F[1]_Fe[0]_B[0.03]_P[0.25,0.25,0.25,0.25]_decay[0.998]_R[300]_norm[bn]_RB[1]_no[-1]_FR[0.1]_Ba[-1]_main_4.pkl", 'rb') as f:
    main_4 = pickle.load(f)

x = [(i+1) * 5 for i in range(len(main_3[0]['single'])-10)]

plt.figure(dpi=120)
plt.grid(b=True, which='major', axis='both')
plt.title('Random Branch w/o KD')

mv_multi_3 = mv_average_10(main_3[0]['multi'])
mv_single_1_3 = mv_average_10([x[0] for x in main_3[0]['single']])
mv_single_2_3 = mv_average_10([x[1] for x in main_3[0]['single']])
mv_single_3_3 = mv_average_10([x[2] for x in main_3[0]['single']])
mv_single_4_3 = mv_average_10([x[3] for x in main_3[0]['single']])

mv_multi_4 = mv_average_10(main_4[0]['multi'])
mv_single_1_4 = mv_average_10([x[0] for x in main_4[0]['single']])
mv_single_2_4 = mv_average_10([x[1] for x in main_4[0]['single']])
mv_single_3_4 = mv_average_10([x[2] for x in main_4[0]['single']])
mv_single_4_4 = mv_average_10([x[3] for x in main_4[0]['single']])

plt.plot(x, mv_multi_3, label = 'Self-FL')
plt.plot(x, mv_single_1_3, label='1/4 Classifier')
plt.plot(x, mv_single_2_3, label='2/4 Classifier')
plt.plot(x, mv_single_3_3, label='3/4 Classifier')
plt.plot(x, mv_single_4_3, label='4/4 Classifier')


print(mv_single_1_3[-1])
print(mv_single_2_3[-1])
print(mv_single_3_3[-1])
print(mv_single_4_3[-1])
print(mv_multi_3[-1])
print('-'*10)
print(mv_single_1_4[-1])
print(mv_single_2_4[-1])
print(mv_single_3_4[-1])
print(mv_single_4_4[-1])
print(mv_multi_4[-1])
print('-'*10)

print(round((mv_single_1_3[-1] + mv_single_1_4[-1])/2,4))
print(round((mv_single_2_3[-1] + mv_single_2_4[-1])/2,4))
print(round((mv_single_3_3[-1] + mv_single_3_4[-1])/2,4))
print(round((mv_single_4_3[-1] + mv_single_4_4[-1])/2,4))
print(round((mv_multi_3[-1] + mv_multi_4[-1])/2,4))

plt.xlabel("Round") 
plt.legend(loc='lower right')
plt.show()
# Out:
# 0.7003
# 0.7259
# 0.7422
# 0.7413
# 0.7725
# ----------
# 0.6991
# 0.7204
# 0.7374
# 0.7362
# 0.7683
# ----------
# 0.6997
# 0.7231
# 0.7398
# 0.7388
# 0.7704

# %%
import matplotlib.pyplot as plt
import pickle


with open("cifar100/N[100]_iid[1]_K[1]_F[1]_Fe[0]_B[0.03]_P[0.0,0.0,0.0,1.0]_decay[0.998]_R[300]_norm[bn]_RB[0]_no[-1]_FR[0.1]_Ba[-1]_main_3.pkl", 'rb') as f:
    main_3 = pickle.load(f)

with open("cifar100/N[100]_iid[1]_K[1]_F[1]_Fe[0]_B[0.03]_P[0.0,0.0,0.0,1.0]_decay[0.998]_R[300]_norm[bn]_RB[0]_no[-1]_FR[0.1]_Ba[-1]_main_4.pkl", 'rb') as f:
    main_4 = pickle.load(f)

x = [(i+1) * 5 for i in range(len(main_3[0]['single'])-10)]

plt.figure(dpi=120)
plt.grid(b=True, which='major', axis='both')
plt.title('Maximum w/ KD')

mv_multi_3 = mv_average_10(main_3[0]['multi'])
mv_single_1_3 = mv_average_10([x[0] for x in main_3[0]['single']])
mv_single_2_3 = mv_average_10([x[1] for x in main_3[0]['single']])
mv_single_3_3 = mv_average_10([x[2] for x in main_3[0]['single']])
mv_single_4_3 = mv_average_10([x[3] for x in main_3[0]['single']])

mv_multi_4 = mv_average_10(main_4[0]['multi'])
mv_single_1_4 = mv_average_10([x[0] for x in main_4[0]['single']])
mv_single_2_4 = mv_average_10([x[1] for x in main_4[0]['single']])
mv_single_3_4 = mv_average_10([x[2] for x in main_4[0]['single']])
mv_single_4_4 = mv_average_10([x[3] for x in main_4[0]['single']])

plt.plot(x, mv_multi_3, label = 'Self-FL')
plt.plot(x, mv_single_1_3, label='1/4 Classifier')
plt.plot(x, mv_single_2_3, label='2/4 Classifier')
plt.plot(x, mv_single_3_3, label='3/4 Classifier')
plt.plot(x, mv_single_4_3, label='4/4 Classifier')


print(mv_single_1_3[-1])
print(mv_single_2_3[-1])
print(mv_single_3_3[-1])
print(mv_single_4_3[-1])
print(mv_multi_3[-1])
print('-'*10)
print(mv_single_1_4[-1])
print(mv_single_2_4[-1])
print(mv_single_3_4[-1])
print(mv_single_4_4[-1])
print(mv_multi_4[-1])
print('-'*10)

print(round((mv_single_1_3[-1] + mv_single_1_4[-1])/2,4))
print(round((mv_single_2_3[-1] + mv_single_2_4[-1])/2,4))
print(round((mv_single_3_3[-1] + mv_single_3_4[-1])/2,4))
print(round((mv_single_4_3[-1] + mv_single_4_4[-1])/2,4))
print(round((mv_multi_3[-1] + mv_multi_4[-1])/2,4))

plt.xlabel("Round") 
plt.legend(loc='lower right')
plt.show()
# Out:
# 0.7245
# 0.7502
# 0.7641
# 0.7638
# 0.782
# ----------
# 0.7217
# 0.7475
# 0.7644
# 0.7637
# 0.7815
# ----------
# 0.7231
# 0.7489
# 0.7642
# 0.7638
# 0.7817

# %%
import matplotlib.pyplot as plt
import pickle


with open("cifar100/N[100]_iid[1]_K[0]_F[1]_Fe[0]_B[0.03]_P[0.0,0.0,0.0,1.0]_decay[0.998]_R[300]_norm[bn]_RB[0]_no[-1]_FR[0.1]_Ba[-1]_main_3.pkl", 'rb') as f:
    main_3 = pickle.load(f)

with open("cifar100/N[100]_iid[1]_K[0]_F[1]_Fe[0]_B[0.03]_P[0.0,0.0,0.0,1.0]_decay[0.998]_R[300]_norm[bn]_RB[0]_no[-1]_FR[0.1]_Ba[-1]_main_4.pkl", 'rb') as f:
    main_4 = pickle.load(f)

x = [(i+1) * 5 for i in range(len(main_3[0]['single'])-10)]

plt.figure(dpi=120)
plt.grid(b=True, which='major', axis='both')
plt.title('Maximum w/o KD')

mv_multi_3 = mv_average_10(main_3[0]['multi'])
mv_single_1_3 = mv_average_10([x[0] for x in main_3[0]['single']])
mv_single_2_3 = mv_average_10([x[1] for x in main_3[0]['single']])
mv_single_3_3 = mv_average_10([x[2] for x in main_3[0]['single']])
mv_single_4_3 = mv_average_10([x[3] for x in main_3[0]['single']])

mv_multi_4 = mv_average_10(main_4[0]['multi'])
mv_single_1_4 = mv_average_10([x[0] for x in main_4[0]['single']])
mv_single_2_4 = mv_average_10([x[1] for x in main_4[0]['single']])
mv_single_3_4 = mv_average_10([x[2] for x in main_4[0]['single']])
mv_single_4_4 = mv_average_10([x[3] for x in main_4[0]['single']])

plt.plot(x, mv_multi_3, label = 'Self-FL')
plt.plot(x, mv_single_1_3, label='1/4 Classifier')
plt.plot(x, mv_single_2_3, label='2/4 Classifier')
plt.plot(x, mv_single_3_3, label='3/4 Classifier')
plt.plot(x, mv_single_4_3, label='4/4 Classifier')


print(mv_single_1_3[-1])
print(mv_single_2_3[-1])
print(mv_single_3_3[-1])
print(mv_single_4_3[-1])
print(mv_multi_3[-1])
print('-'*10)
print(mv_single_1_4[-1])
print(mv_single_2_4[-1])
print(mv_single_3_4[-1])
print(mv_single_4_4[-1])
print(mv_multi_4[-1])
print('-'*10)

print(round((mv_single_1_3[-1] + mv_single_1_4[-1])/2,4))
print(round((mv_single_2_3[-1] + mv_single_2_4[-1])/2,4))
print(round((mv_single_3_3[-1] + mv_single_3_4[-1])/2,4))
print(round((mv_single_4_3[-1] + mv_single_4_4[-1])/2,4))
print(round((mv_multi_3[-1] + mv_multi_4[-1])/2,4))

plt.xlabel("Round") 
plt.legend(loc='lower right')
plt.show()
# Out:
# 0.6938
# 0.7232
# 0.7458
# 0.7445
# 0.7753
# ----------
# 0.6947
# 0.7214
# 0.7438
# 0.7439
# 0.7748
# ----------
# 0.6943
# 0.7223
# 0.7448
# 0.7442
# 0.7751

# %% [markdown]
# ## Own.py

# %%
import matplotlib.pyplot as plt
import pickle


with open("cifar100/K[0]_own.pkl", 'rb') as f:
    main_3 = pickle.load(f)


x = [(i+1) * 5 for i in range(len(main_3[0]['single']))]

plt.figure(dpi=120)
plt.grid(b=True, which='major', axis='both')
plt.title('Own')

# mv_multi_3 = mv_average_10(main_3[0]['multi'])
# mv_single_1_3 = mv_average_10([x[0] for x in main_3[0]['single']])
# mv_single_2_3 = mv_average_10([x[1] for x in main_3[0]['single']])
# mv_single_3_3 = mv_average_10([x[2] for x in main_3[0]['single']])
# mv_single_4_3 = mv_average_10([x[3] for x in main_3[0]['single']])

mv_multi_3 =main_3[0]['multi']
mv_single_1_3 = [x[0] for x in main_3[0]['single']]
mv_single_2_3 = [x[1] for x in main_3[0]['single']]
mv_single_3_3 = [x[2] for x in main_3[0]['single']]
mv_single_4_3 = [x[3] for x in main_3[0]['single']]

plt.plot(x, mv_multi_3, label = 'Self-FL')
plt.plot(x, mv_single_1_3, label='1/4 Classifier')
plt.plot(x, mv_single_2_3, label='2/4 Classifier')
plt.plot(x, mv_single_3_3, label='3/4 Classifier')
plt.plot(x, mv_single_4_3, label='4/4 Classifier')


print(mv_single_1_3[-1])
print(mv_single_2_3[-1])
print(mv_single_3_3[-1])
print(mv_single_4_3[-1])
print(mv_multi_3[-1])

plt.xlabel("Round") 
plt.legend(loc='lower right')
plt.show()
# Out:
# 0.6497
# 0.6654
# 0.7054
# 0.7095
# 0.7299

# %%
cifar_10_num_params = [31.4, 178, 750, 1940] # K
cifar_100_num_params = [0.480, 1.35, 3.84, 12.3] # M

cifar_10_num_macs = [3.46, 23.6, 43.7, 62.6] # M
cifar_100_num_macs = [167, 310, 450, 585] # M

def select_level(id, levels, seed):
    
    i = id / 100
    
    if i < sum(levels[:1]):
        return 0
    elif i < (sum(levels[:2])):
        return 1
    elif i < (sum(levels[:3])):
        return 2
    else:
        return 3

# %%
# interpolation - iid - # parameter

import matplotlib.pyplot as plt
import pickle
import numpy as np

with open("cifar100/iid[1]_K[1].pkl", 'rb') as f:
    interpolation_dict = pickle.load(f)

levels = interpolation_dict['levels']
x = []

for k in range(len(levels)):
    avg_params = 0.
    for i in range(100):
        level = select_level(i, levels[k], seed=0)
        avg_params += cifar_100_num_params[level]
    
    #print("{} / {} / {} / {} : {}, {}".format(levels[k][0], levels[k][1], levels[k][2], levels[k][3], avg_params / 100, y[k]*100))
    avg_params /= 100
    x.append(avg_params)

index_min = min(range(len(x)), key=x.__getitem__)
index_max = max(range(len(x)), key=x.__getitem__)

print(len(x))

for i in range(len(x)):
    x[i] /= 1

y = interpolation_dict['accuracy']

z = np.polyfit(x, y, 1)
p = np.poly1d(z)

print(np.corrcoef(x, y))
plt.figure(dpi=120)
plt.scatter(x, y, color='dimgray')
plt.title("CIFAR100 IID")
plt.plot([x[index_min],x[index_max]],[p(x[index_min]),p(x[index_max])], linestyle='--', label='correlation coefficient : 0.48')
plt.xlabel("Average number of Parameters (1e6)") 
plt.ylabel("Test Accuracy")
plt.legend(loc='lower right')
plt.show()
# Out:
# 50
# [[1.         0.48191428]
#  [0.48191428 1.        ]]

# %%
# interpolation - iid - # macs

import matplotlib.pyplot as plt
import pickle
import numpy as np

with open("cifar100/iid[1]_K[1].pkl", 'rb') as f:
    interpolation_dict = pickle.load(f)

levels = interpolation_dict['levels']
x = []

for k in range(len(levels)):
    avg_macs = 0.
    for i in range(100):
        level = select_level(i, levels[k], seed=0)
        avg_macs += cifar_100_num_macs[level]
        
    avg_macs /= 100
    x.append(avg_macs)

index_min = min(range(len(x)), key=x.__getitem__)
index_max = max(range(len(x)), key=x.__getitem__)

print(len(x))

for i in range(len(x)):
    x[i] /= 100

y = interpolation_dict['accuracy']

z = np.polyfit(x, y, 1)
p = np.poly1d(z)
print(np.corrcoef(x, y))

plt.figure(dpi=120)
plt.scatter(x, y, color='dimgray')
plt.title("CIFAR100 IID")
plt.plot([x[index_min],x[index_max]],[p(x[index_min]),p(x[index_max])], linestyle='--', label='correlation coefficient : 0.84')

plt.xlabel("Average number of MACs (1e8)") 
plt.ylabel("Test Accuracy")
plt.legend(loc='lower right')
plt.show()
# Out:
# 50
# [[1.         0.84394206]
#  [0.84394206 1.        ]]
