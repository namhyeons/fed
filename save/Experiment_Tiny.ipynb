# %%
def mv_average_2(lst):
    mv_lst = []
    for i in range(len(lst)-2):
        mv_lst.append(round(sum(lst[i:i+2]) / 2, 4))
    return mv_lst

# %%
def mv_average_10(lst):
    mv_lst = []
    for i in range(len(lst)-10):
        mv_lst.append(round(sum(lst[i:i+10]) / 10, 4))
    return mv_lst

# %%
import matplotlib.pyplot as plt
import pickle

with open("tiny-imagenet/N[100]_iid[1]_K[0]_F[0]_Fe[0]_B[0.03]_P[0.25,0.25,0.25,0.25]_decay[0.998]_R[300]_norm[bn]_RB[0]_no[-1]_FR[0.1]_Ba[-1]_main_3.pkl", 'rb') as f:
    main_3 = pickle.load(f)

with open("tiny-imagenet/N[100]_iid[1]_K[0]_F[0]_Fe[0]_B[0.03]_P[0.25,0.25,0.25,0.25]_decay[0.998]_R[300]_norm[bn]_RB[0]_no[-1]_FR[0.1]_Ba[-1]_main_4.pkl", 'rb') as f:
    main_4 = pickle.load(f)

with open("tiny-imagenet/N[100]_R[1000]_iid[1]_K[0]_F[0]_B[0]_no[bn]_base_3.pkl", 'rb') as f:
    base_0_3 = pickle.load(f)

with open("tiny-imagenet/N[100]_R[1000]_iid[1]_K[0]_F[0]_B[0]_no[bn]_base_4.pkl", 'rb') as f:
    base_0_4 = pickle.load(f)

with open("tiny-imagenet/N[100]_R[1000]_iid[1]_K[0]_F[0]_B[1]_no[bn]_base_3.pkl", 'rb') as f:
    base_1_3 = pickle.load(f)

with open("tiny-imagenet/N[100]_R[1000]_iid[1]_K[0]_F[0]_B[1]_no[bn]_base_4.pkl", 'rb') as f:
    base_1_4 = pickle.load(f)

with open("tiny-imagenet/N[100]_R[1000]_iid[1]_K[0]_F[0]_B[2]_no[bn]_base_3.pkl", 'rb') as f:
    base_2_3 = pickle.load(f)

with open("tiny-imagenet/N[100]_R[1000]_iid[1]_K[0]_F[0]_B[2]_no[bn]_base_4.pkl", 'rb') as f:
    base_2_4 = pickle.load(f)

with open("tiny-imagenet/N[100]_R[1000]_iid[1]_K[0]_F[0]_B[3]_no[bn]_base_3.pkl", 'rb') as f:
    base_3_3 = pickle.load(f)

with open("tiny-imagenet/N[100]_R[1000]_iid[1]_K[0]_F[0]_B[3]_no[bn]_base_4.pkl", 'rb') as f:
    base_3_4 = pickle.load(f)

x = [(i+1) * 5 for i in range(len(base_0_3[0]['single'])-10)]


mv_multi_3 = mv_average_10(main_3[0]['multi'])
mv_base_0_3 = mv_average_10(base_0_3[0]['multi'])
mv_base_1_3 = mv_average_10(base_1_3[0]['multi'])
mv_base_2_3 = mv_average_10(base_2_3[0]['multi'])
mv_base_3_3 = mv_average_10(base_3_3[0]['multi'])

mv_multi_4 = mv_average_10(main_4[0]['multi'])
mv_base_0_4 = mv_average_10(base_0_4[0]['multi'])
mv_base_1_4 = mv_average_10(base_1_4[0]['multi'])
mv_base_2_4 = mv_average_10(base_2_4[0]['multi'])
mv_base_3_4 = mv_average_10(base_3_4[0]['multi'])



plt.figure(dpi=120)
plt.grid(b=True, which='major', axis='both')
plt.title("Compare with Naive Baselines - Self-FL(FedAvg)")
plt.plot(x, mv_multi_3, label = 'Self-FL')
plt.plot(x, mv_base_0_3, label = 'a-100%')
plt.plot(x, mv_base_1_3, label = 'b-75%')
plt.plot(x, mv_base_2_3, label = 'c-50%')
plt.plot(x, mv_base_3_3, label = 'd-25%')


print(mv_multi_3[-1])
print(mv_base_0_3[-1])
print(mv_base_1_3[-1])
print(mv_base_2_3[-1])
print(mv_base_3_3[-1])
print("------------------")
print(mv_multi_4[-1])
print(mv_base_0_4[-1])
print(mv_base_1_4[-1])
print(mv_base_2_4[-1])
print(mv_base_3_4[-1])
print("------------------")
print(round((mv_multi_3[-1]+mv_multi_4[-1])/2,4))
print(round((mv_base_0_3[-1] + mv_base_0_4[-1])/2,4))
print(round((mv_base_1_3[-1] + mv_base_1_4[-1])/2,4))
print(round((mv_base_2_3[-1] + mv_base_2_4[-1])/2,4))
print(round((mv_base_3_3[-1] + mv_base_3_4[-1])/2,4))


plt.xlabel("Round") 
plt.legend(loc='lower right')
plt.show()
# Out:
# 0.499
# 0.4775
# 0.5148
# 0.4578
# 0.3669
# ------------------
# 0.4987
# 0.4905
# 0.5109
# 0.4685
# 0.3623
# ------------------
# 0.4989
# 0.484
# 0.5129
# 0.4632
# 0.3646

# %%
import matplotlib.pyplot as plt
import pickle

with open("tiny-imagenet/N[100]_iid[1]_K[1]_F[1]_Fe[0]_B[0.03]_P[0.25,0.25,0.25,0.25]_decay[0.998]_R[300]_norm[bn]_RB[0]_no[-1]_FR[0.1]_Ba[-1]_main_3.pkl", 'rb') as f:
    main_3 = pickle.load(f)

with open("tiny-imagenet/N[100]_iid[1]_K[1]_F[1]_Fe[0]_B[0.03]_P[0.25,0.25,0.25,0.25]_decay[0.998]_R[300]_norm[bn]_RB[0]_no[-1]_FR[0.1]_Ba[-1]_main_4.pkl", 'rb') as f:
    main_4 = pickle.load(f)

with open("tiny-imagenet/N[100]_R[1000]_iid[1]_K[1]_F[1]_B[0]_no[bn]_base_3.pkl", 'rb') as f:
    base_0_3 = pickle.load(f)

with open("tiny-imagenet/N[100]_R[1000]_iid[1]_K[1]_F[1]_B[0]_no[bn]_base_4.pkl", 'rb') as f:
    base_0_4 = pickle.load(f)

with open("tiny-imagenet/N[100]_R[1000]_iid[1]_K[1]_F[1]_B[1]_no[bn]_base_3.pkl", 'rb') as f:
    base_1_3 = pickle.load(f)

with open("tiny-imagenet/N[100]_R[1000]_iid[1]_K[1]_F[1]_B[1]_no[bn]_base_4.pkl", 'rb') as f:
    base_1_4 = pickle.load(f)

with open("tiny-imagenet/N[100]_R[1000]_iid[1]_K[1]_F[1]_B[2]_no[bn]_base_3.pkl", 'rb') as f:
    base_2_3 = pickle.load(f)

with open("tiny-imagenet/N[100]_R[1000]_iid[1]_K[1]_F[1]_B[2]_no[bn]_base_4.pkl", 'rb') as f:
    base_2_4 = pickle.load(f)

with open("tiny-imagenet/N[100]_R[1000]_iid[1]_K[1]_F[1]_B[3]_no[bn]_base_3.pkl", 'rb') as f:
    base_3_3 = pickle.load(f)

with open("tiny-imagenet/N[100]_R[1000]_iid[1]_K[1]_F[1]_B[3]_no[bn]_base_4.pkl", 'rb') as f:
    base_3_4 = pickle.load(f)

x = [(i+1) * 5 for i in range(len(base_0_3[0]['single'])-10)]


mv_multi_3 = mv_average_10(main_3[0]['multi'])
mv_base_0_3 = mv_average_10(base_0_3[0]['multi'])
mv_base_1_3 = mv_average_10(base_1_3[0]['multi'])
mv_base_2_3 = mv_average_10(base_2_3[0]['multi'])
mv_base_3_3 = mv_average_10(base_3_3[0]['multi'])

mv_multi_4 = mv_average_10(main_4[0]['multi'])
mv_base_0_4 = mv_average_10(base_0_4[0]['multi'])
mv_base_1_4 = mv_average_10(base_1_4[0]['multi'])
mv_base_2_4 = mv_average_10(base_2_4[0]['multi'])
mv_base_3_4 = mv_average_10(base_3_4[0]['multi'])



plt.figure(dpi=120)
plt.grid(b=True, which='major', axis='both')
plt.title("Compare with Naive Baselines - Self-FL")
plt.plot(x, mv_multi_3, label = 'Self-FL')
plt.plot(x, mv_base_0_3, label = 'a-100%')
plt.plot(x, mv_base_1_3, label = 'b-75%')
plt.plot(x, mv_base_2_3, label = 'c-50%')
plt.plot(x, mv_base_3_3, label = 'd-25%')


print(mv_multi_3[-1])
print(mv_base_0_3[-1])
print(mv_base_1_3[-1])
print(mv_base_2_3[-1])
print(mv_base_3_3[-1])
print("------------------")
print(mv_multi_4[-1])
print(mv_base_0_4[-1])
print(mv_base_1_4[-1])
print(mv_base_2_4[-1])
print(mv_base_3_4[-1])
print("------------------")
print(round((mv_multi_3[-1]+mv_multi_4[-1])/2,4))
print(round((mv_base_0_3[-1] + mv_base_0_4[-1])/2,4))
print(round((mv_base_1_3[-1] + mv_base_1_4[-1])/2,4))
print(round((mv_base_2_3[-1] + mv_base_2_4[-1])/2,4))
print(round((mv_base_3_3[-1] + mv_base_3_4[-1])/2,4))


plt.xlabel("Round") 
plt.legend(loc='lower right')
plt.show()
# Out:
# 0.6008
# 0.5145
# 0.5877
# 0.5407
# 0.4414
# ------------------
# 0.5959
# 0.5107
# 0.5894
# 0.5426
# 0.4373
# ------------------
# 0.5983
# 0.5126
# 0.5886
# 0.5416
# 0.4394

# %%
import matplotlib.pyplot as plt
import pickle


with open("tiny-imagenet/N[100]_iid[1]_K[1]_F[1]_Fe[0]_B[0.03]_P[0.25,0.25,0.25,0.25]_decay[0.998]_R[300]_norm[bn]_RB[0]_no[-1]_FR[0.1]_Ba[-1]_main_3.pkl", 'rb') as f:
    main_3 = pickle.load(f)

with open("tiny-imagenet/N[100]_iid[1]_K[1]_F[1]_Fe[0]_B[0.03]_P[0.25,0.25,0.25,0.25]_decay[0.998]_R[300]_norm[bn]_RB[0]_no[-1]_FR[0.1]_Ba[-1]_main_4.pkl", 'rb') as f:
    main_4 = pickle.load(f)

x = [(i+1) * 5 for i in range(len(main_3[0]['single'])-10)]

plt.figure(dpi=120)
plt.grid(b=True, which='major', axis='both')
plt.title('with KD - iid')

mv_multi_3 = mv_average_10(main_3[0]['multi'])
mv_single_1_3 = mv_average_10([x[0] for x in main_3[0]['single']])
mv_single_2_3 = mv_average_10([x[1] for x in main_3[0]['single']])
mv_single_3_3 = mv_average_10([x[2] for x in main_3[0]['single']])
mv_single_4_3 = mv_average_10([x[3] for x in main_3[0]['single']])

mv_multi_4 = mv_average_10(main_4[0]['multi'])
mv_single_1_4 = mv_average_10([x[0] for x in main_4[0]['single']])
mv_single_2_4 = mv_average_10([x[1] for x in main_4[0]['single']])
mv_single_3_4 = mv_average_10([x[2] for x in main_4[0]['single']])
mv_single_4_4 = mv_average_10([x[3] for x in main_4[0]['single']])

plt.plot(x, mv_multi_3, label = 'Self-FL')
plt.plot(x, mv_single_1_3, label='1/4 Classifier')
plt.plot(x, mv_single_2_3, label='2/4 Classifier')
plt.plot(x, mv_single_3_3, label='3/4 Classifier')
plt.plot(x, mv_single_4_3, label='4/4 Classifier')


print(mv_single_1_3[-1])
print(mv_single_2_3[-1])
print(mv_single_3_3[-1])
print(mv_single_4_3[-1])
print(mv_multi_3[-1])
print('-'*10)
print(mv_single_1_4[-1])
print(mv_single_2_4[-1])
print(mv_single_3_4[-1])
print(mv_single_4_4[-1])
print(mv_multi_4[-1])
print('-'*10)

print(round((mv_single_1_3[-1] + mv_single_1_4[-1])/2,4))
print(round((mv_single_2_3[-1] + mv_single_2_4[-1])/2,4))
print(round((mv_single_3_3[-1] + mv_single_3_4[-1])/2,4))
print(round((mv_single_4_3[-1] + mv_single_4_4[-1])/2,4))
print(round((mv_multi_3[-1] + mv_multi_4[-1])/2,4))

plt.xlabel("Round") 
plt.legend(loc='lower right')
plt.show()
# Out:
# 0.5499
# 0.568
# 0.5512
# 0.554
# 0.6008
# ----------
# 0.5526
# 0.5631
# 0.5476
# 0.5494
# 0.5959
# ----------
# 0.5513
# 0.5655
# 0.5494
# 0.5517
# 0.5983

# %%
import matplotlib.pyplot as plt
import pickle


with open("tiny-imagenet/N[100]_iid[1]_K[0]_F[1]_Fe[0]_B[0.03]_P[0.25,0.25,0.25,0.25]_decay[0.998]_R[300]_norm[bn]_RB[0]_no[-1]_FR[0.1]_Ba[-1]_main_3.pkl", 'rb') as f:
    main_3 = pickle.load(f)

with open("tiny-imagenet/N[100]_iid[1]_K[0]_F[1]_Fe[0]_B[0.03]_P[0.25,0.25,0.25,0.25]_decay[0.998]_R[300]_norm[bn]_RB[0]_no[-1]_FR[0.1]_Ba[-1]_main_4.pkl", 'rb') as f:
    main_4 = pickle.load(f)

x = [(i+1) * 5 for i in range(len(main_3[0]['single'])-10)]

plt.figure(dpi=120)
plt.grid(b=True, which='major', axis='both')
plt.title('without KD - iid')

mv_multi_3 = mv_average_10(main_3[0]['multi'])
mv_single_1_3 = mv_average_10([x[0] for x in main_3[0]['single']])
mv_single_2_3 = mv_average_10([x[1] for x in main_3[0]['single']])
mv_single_3_3 = mv_average_10([x[2] for x in main_3[0]['single']])
mv_single_4_3 = mv_average_10([x[3] for x in main_3[0]['single']])

mv_multi_4 = mv_average_10(main_4[0]['multi'])
mv_single_1_4 = mv_average_10([x[0] for x in main_4[0]['single']])
mv_single_2_4 = mv_average_10([x[1] for x in main_4[0]['single']])
mv_single_3_4 = mv_average_10([x[2] for x in main_4[0]['single']])
mv_single_4_4 = mv_average_10([x[3] for x in main_4[0]['single']])

plt.plot(x, mv_multi_3, label = 'Self-FL')
plt.plot(x, mv_single_1_3, label='1/4 Classifier')
plt.plot(x, mv_single_2_3, label='2/4 Classifier')
plt.plot(x, mv_single_3_3, label='3/4 Classifier')
plt.plot(x, mv_single_4_3, label='4/4 Classifier')


print(mv_single_1_3[-1])
print(mv_single_2_3[-1])
print(mv_single_3_3[-1])
print(mv_single_4_3[-1])
print(mv_multi_3[-1])
print('-'*10)
print(mv_single_1_4[-1])
print(mv_single_2_4[-1])
print(mv_single_3_4[-1])
print(mv_single_4_4[-1])
print(mv_multi_4[-1])
print('-'*10)

print(round((mv_single_1_3[-1] + mv_single_1_4[-1])/2,4))
print(round((mv_single_2_3[-1] + mv_single_2_4[-1])/2,4))
print(round((mv_single_3_3[-1] + mv_single_3_4[-1])/2,4))
print(round((mv_single_4_3[-1] + mv_single_4_4[-1])/2,4))
print(round((mv_multi_3[-1] + mv_multi_4[-1])/2,4))

plt.xlabel("Round") 
plt.legend(loc='lower right')
plt.show()
# Out:
# 0.5131
# 0.5122
# 0.4335
# 0.4321
# 0.5454
# ----------
# 0.508
# 0.5135
# 0.4359
# 0.4365
# 0.546
# ----------
# 0.5106
# 0.5129
# 0.4347
# 0.4343
# 0.5457

# %%
import matplotlib.pyplot as plt
import pickle


with open("tiny-imagenet/N[100]_iid[0]_K[1]_F[1]_Fe[0]_B[0.03]_P[0.25,0.25,0.25,0.25]_decay[0.998]_R[300]_norm[bn]_RB[0]_no[-1]_FR[0.1]_Ba[-1]_main_3.pkl", 'rb') as f:
    main_3 = pickle.load(f)

with open("tiny-imagenet/N[100]_iid[0]_K[1]_F[1]_Fe[0]_B[0.03]_P[0.25,0.25,0.25,0.25]_decay[0.998]_R[300]_norm[bn]_RB[0]_no[-1]_FR[0.1]_Ba[-1]_main_4.pkl", 'rb') as f:
    main_4 = pickle.load(f)

x = [(i+1) * 5 for i in range(len(main_3[0]['single'])-2)]

plt.figure(dpi=120)
plt.grid(b=True, which='major', axis='both')
plt.title('with KD - noniid')

mv_multi_3 = mv_average_2(main_3[0]['multi'])
mv_single_1_3 = mv_average_2([x[0] for x in main_3[0]['single']])
mv_single_2_3 = mv_average_2([x[1] for x in main_3[0]['single']])
mv_single_3_3 = mv_average_2([x[2] for x in main_3[0]['single']])
mv_single_4_3 = mv_average_2([x[3] for x in main_3[0]['single']])

mv_multi_4 = mv_average_2(main_4[0]['multi'])
mv_single_1_4 = mv_average_2([x[0] for x in main_4[0]['single']])
mv_single_2_4 = mv_average_2([x[1] for x in main_4[0]['single']])
mv_single_3_4 = mv_average_2([x[2] for x in main_4[0]['single']])
mv_single_4_4 = mv_average_2([x[3] for x in main_4[0]['single']])

plt.plot(x, mv_multi_4, label = 'Self-FL')
plt.plot(x, mv_single_1_4, label='1/4 Classifier')
plt.plot(x, mv_single_2_4, label='2/4 Classifier')
plt.plot(x, mv_single_3_4, label='3/4 Classifier')
plt.plot(x, mv_single_4_4, label='4/4 Classifier')


print(mv_single_1_3[-1])
print(mv_single_2_3[-1])
print(mv_single_3_3[-1])
print(mv_single_4_3[-1])
print(mv_multi_3[-1])
print('-'*10)
print(mv_single_1_4[-1])
print(mv_single_2_4[-1])
print(mv_single_3_4[-1])
print(mv_single_4_4[-1])
print(mv_multi_4[-1])
print('-'*10)

print(round((mv_single_1_3[-1] + mv_single_1_4[-1])/2,4))
print(round((mv_single_2_3[-1] + mv_single_2_4[-1])/2,4))
print(round((mv_single_3_3[-1] + mv_single_3_4[-1])/2,4))
print(round((mv_single_4_3[-1] + mv_single_4_4[-1])/2,4))
print(round((mv_multi_3[-1] + mv_multi_4[-1])/2,4))

plt.xlabel("Round") 
plt.legend(loc='lower right')
plt.show()
# Out:
# 0.5291
# 0.548
# 0.5173
# 0.5346
# 0.5778
# ----------
# 0.5268
# 0.5546
# 0.5195
# 0.5426
# 0.5866
# ----------
# 0.528
# 0.5513
# 0.5184
# 0.5386
# 0.5822

# %%
import matplotlib.pyplot as plt
import pickle


with open("tiny-imagenet/N[100]_iid[0]_K[0]_F[1]_Fe[0]_B[0.03]_P[0.25,0.25,0.25,0.25]_decay[0.998]_R[300]_norm[bn]_RB[0]_no[-1]_FR[0.1]_Ba[-1]_main_3.pkl", 'rb') as f:
    main_3 = pickle.load(f)

with open("tiny-imagenet/N[100]_iid[0]_K[0]_F[1]_Fe[0]_B[0.03]_P[0.25,0.25,0.25,0.25]_decay[0.998]_R[300]_norm[bn]_RB[0]_no[-1]_FR[0.1]_Ba[-1]_main_4.pkl", 'rb') as f:
    main_4 = pickle.load(f)

x = [(i+1) * 5 for i in range(len(main_3[0]['single'])-2)]

plt.figure(dpi=120)
plt.grid(b=True, which='major', axis='both')
plt.title('without KD - noniid')

mv_multi_3 = mv_average_2(main_3[0]['multi'])
mv_single_1_3 = mv_average_2([x[0] for x in main_3[0]['single']])
mv_single_2_3 = mv_average_2([x[1] for x in main_3[0]['single']])
mv_single_3_3 = mv_average_2([x[2] for x in main_3[0]['single']])
mv_single_4_3 = mv_average_2([x[3] for x in main_3[0]['single']])

mv_multi_4 = mv_average_2(main_4[0]['multi'])
mv_single_1_4 = mv_average_2([x[0] for x in main_4[0]['single']])
mv_single_2_4 = mv_average_2([x[1] for x in main_4[0]['single']])
mv_single_3_4 = mv_average_2([x[2] for x in main_4[0]['single']])
mv_single_4_4 = mv_average_2([x[3] for x in main_4[0]['single']])

plt.plot(x, mv_multi_4, label = 'Self-FL')
plt.plot(x, mv_single_1_4, label='1/4 Classifier')
plt.plot(x, mv_single_2_4, label='2/4 Classifier')
plt.plot(x, mv_single_3_4, label='3/4 Classifier')
plt.plot(x, mv_single_4_4, label='4/4 Classifier')


print(mv_single_1_3[-1])
print(mv_single_2_3[-1])
print(mv_single_3_3[-2])
print(mv_single_4_3[-1])
print(mv_multi_3[-1])
print('-'*10)
print(mv_single_1_4[-1])
print(mv_single_2_4[-1])
print(mv_single_3_4[-1])
print(mv_single_4_4[-1])
print(mv_multi_4[-1])
print('-'*10)

print(round((mv_single_1_3[-1] + mv_single_1_4[-1])/2,4))
print(round((mv_single_2_3[-1] + mv_single_2_4[-1])/2,4))
print(round((mv_single_3_3[-2] + mv_single_3_4[-1])/2,4))
print(round((mv_single_4_3[-1] + mv_single_4_4[-1])/2,4))
print(round((mv_multi_3[-1] + mv_multi_4[-1])/2,4))

plt.xlabel("Round") 
plt.legend(loc='lower right')
plt.show()
# Out:
# 0.4884
# 0.4922
# 0.4381
# 0.4355
# 0.5242
# ----------
# 0.493
# 0.5019
# 0.4218
# 0.4406
# 0.5364
# ----------
# 0.4907
# 0.497
# 0.4299
# 0.438
# 0.5303

# %%
import matplotlib.pyplot as plt
import pickle


with open("tiny-imagenet/N[100]_iid[1]_K[1]_F[1]_Fe[0]_B[0.03]_P[0.25,0.25,0.25,0.25]_decay[0.998]_R[300]_norm[bn]_RB[1]_no[-1]_FR[0.1]_Ba[-1]_main_3.pkl", 'rb') as f:
    main_3 = pickle.load(f)

with open("tiny-imagenet/N[100]_iid[1]_K[1]_F[1]_Fe[0]_B[0.03]_P[0.25,0.25,0.25,0.25]_decay[0.998]_R[300]_norm[bn]_RB[1]_no[-1]_FR[0.1]_Ba[-1]_main_4.pkl", 'rb') as f:
    main_4 = pickle.load(f)

x = [(i+1) * 5 for i in range(len(main_3[0]['single'])-10)]

plt.figure(dpi=120)
plt.grid(b=True, which='major', axis='both')
plt.title('Random Branch w/ KD')

mv_multi_3 = mv_average_10(main_3[0]['multi'])
mv_single_1_3 = mv_average_10([x[0] for x in main_3[0]['single']])
mv_single_2_3 = mv_average_10([x[1] for x in main_3[0]['single']])
mv_single_3_3 = mv_average_10([x[2] for x in main_3[0]['single']])
mv_single_4_3 = mv_average_10([x[3] for x in main_3[0]['single']])

mv_multi_4 = mv_average_10(main_4[0]['multi'])
mv_single_1_4 = mv_average_10([x[0] for x in main_4[0]['single']])
mv_single_2_4 = mv_average_10([x[1] for x in main_4[0]['single']])
mv_single_3_4 = mv_average_10([x[2] for x in main_4[0]['single']])
mv_single_4_4 = mv_average_10([x[3] for x in main_4[0]['single']])

plt.plot(x, mv_multi_3, label = 'Self-FL')
plt.plot(x, mv_single_1_3, label='1/4 Classifier')
plt.plot(x, mv_single_2_3, label='2/4 Classifier')
plt.plot(x, mv_single_3_3, label='3/4 Classifier')
plt.plot(x, mv_single_4_3, label='4/4 Classifier')


print(mv_single_1_3[-1])
print(mv_single_2_3[-1])
print(mv_single_3_3[-1])
print(mv_single_4_3[-1])
print(mv_multi_3[-1])
print('-'*10)
print(mv_single_1_4[-1])
print(mv_single_2_4[-1])
print(mv_single_3_4[-1])
print(mv_single_4_4[-1])
print(mv_multi_4[-1])
print('-'*10)

print(round((mv_single_1_3[-1] + mv_single_1_4[-1])/2,4))
print(round((mv_single_2_3[-1] + mv_single_2_4[-1])/2,4))
print(round((mv_single_3_3[-1] + mv_single_3_4[-1])/2,4))
print(round((mv_single_4_3[-1] + mv_single_4_4[-1])/2,4))
print(round((mv_multi_3[-1] + mv_multi_4[-1])/2,4))

plt.xlabel("Round") 
plt.legend(loc='lower right')
plt.show()
# Out:
# 0.5587
# 0.5922
# 0.6012
# 0.6009
# 0.624
# ----------
# 0.56
# 0.5909
# 0.6015
# 0.6013
# 0.6221
# ----------
# 0.5594
# 0.5916
# 0.6014
# 0.6011
# 0.623

# %%
import matplotlib.pyplot as plt
import pickle


with open("tiny-imagenet/N[100]_iid[1]_K[0]_F[1]_Fe[0]_B[0.03]_P[0.25,0.25,0.25,0.25]_decay[0.998]_R[300]_norm[bn]_RB[1]_no[-1]_FR[0.1]_Ba[-1]_main_3.pkl", 'rb') as f:
    main_3 = pickle.load(f)

with open("tiny-imagenet/N[100]_iid[1]_K[0]_F[1]_Fe[0]_B[0.03]_P[0.25,0.25,0.25,0.25]_decay[0.998]_R[300]_norm[bn]_RB[1]_no[-1]_FR[0.1]_Ba[-1]_main_4.pkl", 'rb') as f:
    main_4 = pickle.load(f)

x = [(i+1) * 5 for i in range(len(main_3[0]['single'])-10)]

plt.figure(dpi=120)
plt.grid(b=True, which='major', axis='both')
plt.title('Random Branch w/o KD')

mv_multi_3 = mv_average_10(main_3[0]['multi'])
mv_single_1_3 = mv_average_10([x[0] for x in main_3[0]['single']])
mv_single_2_3 = mv_average_10([x[1] for x in main_3[0]['single']])
mv_single_3_3 = mv_average_10([x[2] for x in main_3[0]['single']])
mv_single_4_3 = mv_average_10([x[3] for x in main_3[0]['single']])

mv_multi_4 = mv_average_10(main_4[0]['multi'])
mv_single_1_4 = mv_average_10([x[0] for x in main_4[0]['single']])
mv_single_2_4 = mv_average_10([x[1] for x in main_4[0]['single']])
mv_single_3_4 = mv_average_10([x[2] for x in main_4[0]['single']])
mv_single_4_4 = mv_average_10([x[3] for x in main_4[0]['single']])

plt.plot(x, mv_multi_3, label = 'Self-FL')
plt.plot(x, mv_single_1_3, label='1/4 Classifier')
plt.plot(x, mv_single_2_3, label='2/4 Classifier')
plt.plot(x, mv_single_3_3, label='3/4 Classifier')
plt.plot(x, mv_single_4_3, label='4/4 Classifier')


print(mv_single_1_3[-1])
print(mv_single_2_3[-1])
print(mv_single_3_3[-1])
print(mv_single_4_3[-1])
print(mv_multi_3[-1])
print('-'*10)
print(mv_single_1_4[-1])
print(mv_single_2_4[-1])
print(mv_single_3_4[-1])
print(mv_single_4_4[-1])
print(mv_multi_4[-1])
print('-'*10)

print(round((mv_single_1_3[-1] + mv_single_1_4[-1])/2,4))
print(round((mv_single_2_3[-1] + mv_single_2_4[-1])/2,4))
print(round((mv_single_3_3[-1] + mv_single_3_4[-1])/2,4))
print(round((mv_single_4_3[-1] + mv_single_4_4[-1])/2,4))
print(round((mv_multi_3[-1] + mv_multi_4[-1])/2,4))

plt.xlabel("Round") 
plt.legend(loc='lower right')
plt.show()
# Out:
# 0.5117
# 0.5479
# 0.5379
# 0.5403
# 0.5972
# ----------
# 0.5108
# 0.5472
# 0.5416
# 0.5466
# 0.5972
# ----------
# 0.5112
# 0.5475
# 0.5397
# 0.5434
# 0.5972

# %%
import matplotlib.pyplot as plt
import pickle


with open("tiny-imagenet/N[100]_iid[1]_K[1]_F[1]_Fe[0]_B[0.03]_P[0.0,0.0,0.0,1.0]_decay[0.998]_R[300]_norm[bn]_RB[0]_no[-1]_FR[0.1]_Ba[-1]_main_3.pkl", 'rb') as f:
    main_3 = pickle.load(f)

with open("tiny-imagenet/N[100]_iid[1]_K[1]_F[1]_Fe[0]_B[0.03]_P[0.0,0.0,0.0,1.0]_decay[0.998]_R[300]_norm[bn]_RB[0]_no[-1]_FR[0.1]_Ba[-1]_main_4.pkl", 'rb') as f:
    main_4 = pickle.load(f)

x = [(i+1) * 5 for i in range(len(main_3[0]['single'])-10)]

plt.figure(dpi=120)
plt.grid(b=True, which='major', axis='both')
plt.title('Maximum w/ KD')

mv_multi_3 = mv_average_10(main_3[0]['multi'])
mv_single_1_3 = mv_average_10([x[0] for x in main_3[0]['single']])
mv_single_2_3 = mv_average_10([x[1] for x in main_3[0]['single']])
mv_single_3_3 = mv_average_10([x[2] for x in main_3[0]['single']])
mv_single_4_3 = mv_average_10([x[3] for x in main_3[0]['single']])

mv_multi_4 = mv_average_10(main_4[0]['multi'])
mv_single_1_4 = mv_average_10([x[0] for x in main_4[0]['single']])
mv_single_2_4 = mv_average_10([x[1] for x in main_4[0]['single']])
mv_single_3_4 = mv_average_10([x[2] for x in main_4[0]['single']])
mv_single_4_4 = mv_average_10([x[3] for x in main_4[0]['single']])

plt.plot(x, mv_multi_3, label = 'Self-FL')
plt.plot(x, mv_single_1_3, label='1/4 Classifier')
plt.plot(x, mv_single_2_3, label='2/4 Classifier')
plt.plot(x, mv_single_3_3, label='3/4 Classifier')
plt.plot(x, mv_single_4_3, label='4/4 Classifier')


print(mv_single_1_3[-1])
print(mv_single_2_3[-1])
print(mv_single_3_3[-1])
print(mv_single_4_3[-1])
print(mv_multi_3[-1])
print('-'*10)
print(mv_single_1_4[-1])
print(mv_single_2_4[-1])
print(mv_single_3_4[-1])
print(mv_single_4_4[-1])
print(mv_multi_4[-1])
print('-'*10)

print(round((mv_single_1_3[-1] + mv_single_1_4[-1])/2,4))
print(round((mv_single_2_3[-1] + mv_single_2_4[-1])/2,4))
print(round((mv_single_3_3[-1] + mv_single_3_4[-1])/2,4))
print(round((mv_single_4_3[-1] + mv_single_4_4[-1])/2,4))
print(round((mv_multi_3[-1] + mv_multi_4[-1])/2,4))

plt.xlabel("Round") 
plt.legend(loc='lower right')
plt.show()
# Out:
# 0.5607
# 0.5914
# 0.6044
# 0.6108
# 0.6316
# ----------
# 0.5584
# 0.5913
# 0.6005
# 0.6056
# 0.6281
# ----------
# 0.5595
# 0.5914
# 0.6025
# 0.6082
# 0.6299

# %%
import matplotlib.pyplot as plt
import pickle


with open("tiny-imagenet/N[100]_iid[1]_K[0]_F[1]_Fe[0]_B[0.03]_P[0.0,0.0,0.0,1.0]_decay[0.998]_R[300]_norm[bn]_RB[0]_no[-1]_FR[0.1]_Ba[-1]_main_3.pkl", 'rb') as f:
    main_3 = pickle.load(f)

with open("tiny-imagenet/N[100]_iid[1]_K[0]_F[1]_Fe[0]_B[0.03]_P[0.0,0.0,0.0,1.0]_decay[0.998]_R[300]_norm[bn]_RB[0]_no[-1]_FR[0.1]_Ba[-1]_main_4.pkl", 'rb') as f:
    main_4 = pickle.load(f)

x = [(i+1) * 5 for i in range(len(main_3[0]['single'])-10)]

plt.figure(dpi=120)
plt.grid(b=True, which='major', axis='both')
plt.title('Maximum w/o KD')

mv_multi_3 = mv_average_10(main_3[0]['multi'])
mv_single_1_3 = mv_average_10([x[0] for x in main_3[0]['single']])
mv_single_2_3 = mv_average_10([x[1] for x in main_3[0]['single']])
mv_single_3_3 = mv_average_10([x[2] for x in main_3[0]['single']])
mv_single_4_3 = mv_average_10([x[3] for x in main_3[0]['single']])

mv_multi_4 = mv_average_10(main_4[0]['multi'])
mv_single_1_4 = mv_average_10([x[0] for x in main_4[0]['single']])
mv_single_2_4 = mv_average_10([x[1] for x in main_4[0]['single']])
mv_single_3_4 = mv_average_10([x[2] for x in main_4[0]['single']])
mv_single_4_4 = mv_average_10([x[3] for x in main_4[0]['single']])

plt.plot(x, mv_multi_3, label = 'Self-FL')
plt.plot(x, mv_single_1_3, label='1/4 Classifier')
plt.plot(x, mv_single_2_3, label='2/4 Classifier')
plt.plot(x, mv_single_3_3, label='3/4 Classifier')
plt.plot(x, mv_single_4_3, label='4/4 Classifier')


print(mv_single_1_3[-1])
print(mv_single_2_3[-1])
print(mv_single_3_3[-1])
print(mv_single_4_3[-1])
print(mv_multi_3[-1])
print('-'*10)
print(mv_single_1_4[-1])
print(mv_single_2_4[-1])
print(mv_single_3_4[-1])
print(mv_single_4_4[-1])
print(mv_multi_4[-1])
print('-'*10)

print(round((mv_single_1_3[-1] + mv_single_1_4[-1])/2,4))
print(round((mv_single_2_3[-1] + mv_single_2_4[-1])/2,4))
print(round((mv_single_3_3[-1] + mv_single_3_4[-1])/2,4))
print(round((mv_single_4_3[-1] + mv_single_4_4[-1])/2,4))
print(round((mv_multi_3[-1] + mv_multi_4[-1])/2,4))

plt.xlabel("Round") 
plt.legend(loc='lower right')
plt.show()
# Out:
# 0.5083
# 0.5505
# 0.5358
# 0.5445
# 0.6009
# ----------
# 0.5082
# 0.5495
# 0.538
# 0.5447
# 0.6015
# ----------
# 0.5082
# 0.55
# 0.5369
# 0.5446
# 0.6012
